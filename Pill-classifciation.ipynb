# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np
import pandas as pd
import os
import re
from PIL import Image
import shutil
import xml.etree.ElementTree as et
import random
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

import tensorflow.keras as keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image
from sklearn.metrics import confusion_matrix, roc_curve
from sklearn.model_selection import train_test_split
import seaborn as sns

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.7.0
# 2.7.0

# %%
tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)
# True
# Out:
# WARNING:tensorflow:From C:\Users\ksjljk1030\AppData\Local\Temp\ipykernel_15576\3356506064.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
data_dir = '/Users/ksjljk1030/drug_image3/'
image_dir = os.path.join(data_dir, 'real_image2')
print(image_dir)
bbox_dir = os.path.join(data_dir, 'annotation2')
print(bbox_dir)
#aug_data = = os.path.join(data_dir, 'imgaug')
#print(aug_data)
# Out:
# /Users/ksjljk1030/drug_image3/real_image2
# /Users/ksjljk1030/drug_image3/annotation2

# %%
image_files = [fname for fname in os.listdir(image_dir) if os.path.splitext(fname)[-1] == '.jpg']
print(len(image_files))
image_files[:5]
# Out:
# 30000
# ['가나릴정.jpg', '가나릴정_1.jpg', '가나릴정_2.jpg', '가나릴정_3.jpg', '가나릴정_4.jpg']

# %%
class_list = set()
for image_file in image_files:
    file_name = re.split('[/,(,). :, _]',image_file)[-2]
    class_name = re.split('[/,(,). :, _]',image_file)[-2]
    if class_name =='1' or class_name =='2' or class_name =='3' or class_name =='4' or class_name =='5' or class_name =='6' or class_name =='7' or class_name =='8' or class_name =='9':
        continue
    class_list.add(class_name)
class_list = list(class_list)
print(len(class_list))
print(class_list)
# Out:
# 3000
# ['리바롤정15밀리그램', '니카렌정', '뉴질렉트정1밀리그램', '레보카신정', '리페노딜정', '다이릭스정', '바소빅스정', '라베라엠정20밀리그램', '나프로정', '로비큐아정25밀리그램', '로바르탄정20', '메포딘정500밀리그램', '라시딘정150mg', '누제정', '라베정20밀리그램', '미라펙스정1', '리마맥스정', '라사질트정0', '녹십자폴산정', '뮤페신정', '뮤코라제비정', '명문아스피린장용정100mg', '리버티정10밀리그램', '로수넥스정5mg', '더게인디정', '로트로반정10밀리그램', '라베톤정20밀리그람', '뉴로페질정10밀리그램', '다나진정10mg', '멜아웃정', '나라프릴정10mg', '나노디오정600밀리그램', '라사원정1', '메가클로페낙정', '넬슨시메티딘정200밀리그램', '레썰피정', '메바린정', '네오페질정10밀리그램', '도네셉트정5밀리그램', '글로에리손정', '마도파정125', '글레존정', '로바스트정', '미옥틴정', '라베칸정20밀리그램', '레보론정25밀리그램', '나토실정', '로수토정20밀리그램', '네볼민정', '디멘도네정10밀리그램', '라비트라정', '명문라푸티딘정10밀리그램', '디트라정', '리바록스정15밀리그램', '로바콜정', '도네질오디정10밀리그램', '리반틸정15밀리그램', '대우에날라프릴정10밀리그램', '로수바스타퀄정20밀리그램', '글라딘정2밀리그램', '모놀레어츄정5밀리그램', '뉴로케어정10mg', '로슈바정10mg', '바난정', '레모신에프트로키', '가트정', '네오키디츄어블정', '몬테포스츄정5mg', '라토딘정10밀리그램', '메티졸정5밀리그램', '넥소메라정40밀리그램', '메녹틸정', '바로시드정', '대원헤데라정', '다